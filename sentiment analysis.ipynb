# %%
import requests
import json
import pandas as pd

# %%
url = "https://twitter-data1.p.rapidapi.com/Search/"

querystring = {"q":"Jakarta", "lang":"en", "count":"100"}

headers = {
	"X-RapidAPI-Key": "a6129818camshba593fc1a0fb7dbp109dabjsn602bb7495377",
	"X-RapidAPI-Host": "twitter-data1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = json.loads(requests.get(url, headers=headers, params=querystring).text)

# %%
data_to_collect = data["globalObjects"]["tweets"]

# %%
data_to_collect.values()

# %%
tweet_data = pd.DataFrame(columns=["tweet_created", "tweet_id", "tweet"])

for tweet in data_to_collect.values():
    tweet_created = tweet["created_at"]
    tweet_id = tweet["id_str"]
    tweet_value = tweet["full_text"]
    tweet_source = tweet["source"]
    tweet_data = tweet_data.append({"tweet_created": tweet_created, "tweet_id": tweet_id, "tweet": tweet_value, "tweet_source": tweet_source}, ignore_index=True)

# %%
my_new_string = tweet_data["tweet_source"].replace('<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', "Twitter for Android").replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', "Twitter for iPhone").replace('<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', "Twitter Web App").replace('<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">advertiser-interface</a>', "Other")

# %%
tweet_data["tweet_source"] = my_new_string
tweet_data
# Out:
#                      tweet_created             tweet_id  \
# 0   Mon Apr 17 14:12:22 +0000 2023  1647966234724675588
# 1   Mon Apr 17 05:31:27 +0000 2023  1647835139278528513
# 2   Tue Apr 18 08:56:54 +0000 2023  1648249233840164865
# 3   Sun Apr 16 07:29:18 +0000 2023  1647502412805197828
# 4   Sun Apr 16 14:18:03 +0000 2023  1647605277007691777
# 5   Tue Apr 18 00:46:23 +0000 2023  1648125790721282048
# 6   Sat Apr 15 07:43:28 +0000 2023  1647143586587365377
# 7   Fri Apr 14 13:45:33 +0000 2023  1646872319770636291
# 8   Sun Apr 16 07:34:21 +0000 2023  1647503683146633216
# 9   Tue Apr 18 08:14:10 +0000 2023  1648238478692581376
# 10  Sun Apr 16 07:22:01 +0000 2023  1647500579567194113
# 11  Sat Apr 15 17:57:37 +0000 2023  1647298142713561088
# 12  Tue Apr 18 08:08:33 +0000 2023  1648237064197132289
# 13  Mon Apr 17 13:54:56 +0000 2023  1647961848195473409
# 14  Mon Apr 17 17:56:53 +0000 2023  1648022735833141248
# 15  Thu Apr 13 09:00:02 +0000 2023  1646438079652311041
# 16  Tue Apr 18 09:44:11 +0000 2023  1648261130203045888
# 17  Tue Apr 18 09:16:57 +0000 2023  1648254278598037505
# 18  Mon Apr 17 03:48:31 +0000 2023  1647809238344019968
# 19  Mon Apr 17 10:07:42 +0000 2023  1647904661440184320
# 20  Mon Apr 17 02:49:37 +0000 2023  1647794415459770370
# 21  Tue Apr 18 07:05:19 +0000 2023  1648221149179019264
# 22  Tue Apr 18 01:02:29 +0000 2023  1648129840820920320
# 23  Sun Apr 16 17:48:27 +0000 2023  1647658224462729217
#
#                                                 tweet  \
# 0   Freebies WayV Fanmeeting Tour [Phantom] in Jak...
# 1   A cool place in Jakarta is the basement of Blo...
# 2   [ INA GO 🇮🇩 ]\n\nPO BEAUTY+ MAGAZINE 2023.05\n...
# 3   moodz! see you in jakarta 😆  \n \n   https://t...
# 4   Availabe.\nJakarta. kost alone\nWa. 0838-5292-...
# 5   #India’s ‘unknown’ biggest airline pushes for ...
# 6   AD Material for #DAESUNG #BIGBANG Support-Fans...
# 7   nahyuck moment in The dream show 2 Jakarta #na...
# 8   Giveaway 1 Tiket Fanmeet WayV atau Cash 1.785....
# 9      @tanyarlfes bro thinks jakarta is in greenland
# 10  💙 woodz_dnwm live instagram 🧡\n\n💙 “See you in...
# 11  Berita Duka.\n\nTelah hilang jalur pedestrian ...
# 12  𝗧𝗢𝗞𝗬𝗢 | 𝗕𝗟𝗨𝗘 𝗧𝗘𝗔𝗠🔵 | 𝟬𝟳.𝟮𝟵(𝗦𝗔𝗧)  \n独創的な世界観、無限の...
# 13  B.I 2023 Asia Tour [L.O.L THE HIDDEN STAGE] in...
# 14  @garega17 @tatakujiyati Jakarta macet karena b...
# 15                 where is that one nahyuck video? 🤔
# 16  so im getting mingi like he was in JAKARTA aga...
# 17  ; MANIAC in Jakarta – 131122\n\nyes i got home...
# 18  Tau gak yang ngeselin soal trotoar dan jalur s...
# 19  the jakarta woodz concert sold out in 5 minute...
# 20  i made this indomie inspired sign 🐑\n\n#YANGYA...
# 21  Biggest Power Night report from Istiqlal Mosqu...
# 22  LOOOLLLL I FOUND HOONSUK MOMENT AT HELLO TOUR ...
# 23                            https://t.co/qSkKlS3aH9
#
#                                          tweet_source
# 0                                  Twitter for iPhone
# 1                                  Twitter for iPhone
# 2                                  Twitter for iPhone
# 3   <a href="http://itunes.apple.com/us/app/twitte...
# 4                                 Twitter for Android
# 5                                  Twitter for iPhone
# 6                                 Twitter for Android
# 7                                  Twitter for iPhone
# 8                                 Twitter for Android
# 9                                 Twitter for Android
# 10                                 Twitter for iPhone
# 11                                    Twitter Web App
# 12                                    Twitter Web App
# 13                                Twitter for Android
# 14                                    Twitter Web App
# 15                                 Twitter for iPhone
# 16                                 Twitter for iPhone
# 17                                 Twitter for iPhone
# 18                                 Twitter for iPhone
# 19                                 Twitter for iPhone
# 20                                 Twitter for iPhone
# 21                                    Twitter Web App
# 22                                Twitter for Android
# 23                                 Twitter for iPhone

# %%
tweet_data.to_csv("tweet.csv")

# %%
import re
from textblob import TextBlob

# %%
for tweets in data_to_collect.values():
    tweets_properties = {}
    tweets_properties["tweets_created"] = tweets["created_at"]
    tweets_properties["tweets_id"] = tweets["id_str"]
    tweets_properties["tweets"] = tweets["full_text"]
    cleaned_tweets = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweets["full_text"]).split())
    tweets_properties["tweets"] = cleaned_tweets

    analysis = TextBlob(cleaned_tweets)
    if analysis.sentiment.polarity > 0.0:
        tweets_properties["sentiment"] = "Positif"
    elif analysis.sentiment.polarity == 0.0:
        tweets_properties["sentiment"] = "Netral"
    else:
        tweets_properties["sentiment"] = "Negatif"
    print(tweets_properties)
# Out:
# {'tweets_created': 'Mon Apr 17 14:12:22 +0000 2023', 'tweets_id': '1647966234724675588', 'tweets': 'Freebies WayV Fanmeeting Tour Phantom in Jakarta o o ICE BSD detail tba Saturday April 29th 2023 TBA WayV Phantom WayV Phantom in JAKARTA HENDERY', 'sentiment': 'Netral'}
# {'tweets_created': 'Mon Apr 17 05:31:27 +0000 2023', 'tweets_id': '1647835139278528513', 'tweets': 'A cool place in Jakarta is the basement of Block M Square In a chaotic maze of small shops and stalls you find a lot of used book shops selling used amp antique books Mostly Indonesian but also some very interesting English or Dutch books on Indonesia 1 3', 'sentiment': 'Positif'}
# {'tweets_created': 'Tue Apr 18 08:56:54 +0000 2023', 'tweets_id': '1648249233840164865', 'tweets': 'INA GO PO BEAUTY MAGAZINE 2023 05 COVER WENDY Harga Magz IDR 155K DP 105K Form PO Close PO PO 23 04 23 Note Cargo Tax est 500gr Bank QRIS Grup Line WA Jakarta', 'sentiment': 'Netral'}
# {'tweets_created': 'Sun Apr 16 07:29:18 +0000 2023', 'tweets_id': '1647502412805197828', 'tweets': 'moodz see you in jakarta', 'sentiment': 'Netral'}
# {'tweets_created': 'Sun Apr 16 14:18:03 +0000 2023', 'tweets_id': '1647605277007691777', 'tweets': 'Availabe Jakarta kost alone Wa 0838 5292 5786 Privacy for you New account Pleas rt', 'sentiment': 'Positif'}
# {'tweets_created': 'Tue Apr 18 00:46:23 +0000 2023', 'tweets_id': '1648125790721282048', 'tweets': 'India s unknown biggest airline pushes for global expansion s sayan2015 on IndiGo which will soon be flying to Nairobi and Jakarta and is in talks on a code sharing deal to expand its operations to the US', 'sentiment': 'Negatif'}
# {'tweets_created': 'Sat Apr 15 07:43:28 +0000 2023', 'tweets_id': '1647143586587365377', 'tweets': 'AD Material for DAESUNG BIGBANG Support Fans Ad Location Outdoor LED Screen Mall of Indonesia Jakarta Ad Period April 17 April 30 2023 Queeri Queeri Vote', 'sentiment': 'Netral'}
# {'tweets_created': 'Fri Apr 14 13:45:33 +0000 2023', 'tweets_id': '1646872319770636291', 'tweets': 'nahyuck moment in The dream show 2 Jakarta nahyuck THEDREAMSHOW2 in JAKARTA', 'sentiment': 'Netral'}
# {'tweets_created': 'Sun Apr 16 07:34:21 +0000 2023', 'tweets_id': '1647503683146633216', 'tweets': 'Giveaway 1 Tiket Fanmeet WayV atau Cash 1 785 000 IDR Retweet like follow me End tanggal 22 april WayV Phantom in JAKARTA', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 08:14:10 +0000 2023', 'tweets_id': '1648238478692581376', 'tweets': 'bro thinks jakarta is in greenland', 'sentiment': 'Netral'}
# {'tweets_created': 'Sun Apr 16 07:22:01 +0000 2023', 'tweets_id': '1647500579567194113', 'tweets': 'woodz dnwm live instagram See you in Jakarta see you Can t wait to see you in Jakarta me to really INA MOODZ AYOK SIAP2 BUAT TUAN MUDA CHO DISINI WOODZ', 'sentiment': 'Positif'}
# {'tweets_created': 'Sat Apr 15 17:57:37 +0000 2023', 'tweets_id': '1647298142713561088', 'tweets': 'Berita Duka Telah hilang jalur pedestrian dan jalur sepeda di Jalan Santa Jakarta Selatan Dalihnya solusi macet', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 08:08:33 +0000 2023', 'tweets_id': '1648237064197132289', 'tweets': 'Let s burn 4 25 5', 'sentiment': 'Netral'}
# {'tweets_created': 'Mon Apr 17 13:54:56 +0000 2023', 'tweets_id': '1647961848195473409', 'tweets': 'B I 2023 Asia Tour L O L THE HIDDEN STAGE in Jakarta Photos by Three Angles Pro', 'sentiment': 'Negatif'}
# {'tweets_created': 'Mon Apr 17 17:56:53 +0000 2023', 'tweets_id': '1648022735833141248', 'tweets': 'Jakarta macet karena budaya kita tentang kekayaan adalah memiliki mobil Masyarakat kita percaya bahwa ukuran kita kaya adalah naik mobil sndiri itu aja keliru Jadi yg anies lakukan adalah contra mass culture melawan budaya yg keliru dalam lingkup transportasi', 'sentiment': 'Netral'}
# {'tweets_created': 'Thu Apr 13 09:00:02 +0000 2023', 'tweets_id': '1646438079652311041', 'tweets': 'where is that one nahyuck video', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 09:44:11 +0000 2023', 'tweets_id': '1648261130203045888', 'tweets': 'so im getting mingi like he was in JAKARTA again but x2 IM SEATED BITCH', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 09:16:57 +0000 2023', 'tweets_id': '1648254278598037505', 'tweets': 'MANIAC in Jakarta 131122 yes i got home with some bruises bcs sempet jatuh di section ku lol but the concert was SUPER FUN and worth it like i enjoyed the concert so much sampe kaget tetiba udah di ujung acara take me back', 'sentiment': 'Positif'}
# {'tweets_created': 'Mon Apr 17 03:48:31 +0000 2023', 'tweets_id': '1647809238344019968', 'tweets': 'Tau gak yang ngeselin soal trotoar dan jalur sepeda jakarta Ketika lo protes penghapusannya lo langsung dituduh pendukung Anies Padahal kebijakan kalau bagus ya bagus aja jelek ya jelek aja Nah ini contoh yang jelek', 'sentiment': 'Netral'}
# {'tweets_created': 'Mon Apr 17 10:07:42 +0000 2023', 'tweets_id': '1647904661440184320', 'tweets': 'the jakarta woodz concert sold out in 5 minutes that s insane', 'sentiment': 'Negatif'}
# {'tweets_created': 'Mon Apr 17 02:49:37 +0000 2023', 'tweets_id': '1647794415459770370', 'tweets': 'i made this indomie inspired sign YANGYANG WayV Phantom in Jakarta', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 07:05:19 +0000 2023', 'tweets_id': '1648221149179019264', 'tweets': 'Biggest Power Night report from Istiqlal Mosque Jakarta', 'sentiment': 'Netral'}
# {'tweets_created': 'Tue Apr 18 01:02:29 +0000 2023', 'tweets_id': '1648129840820920320', 'tweets': 'LOOOLLLL I FOUND HOONSUK MOMENT AT HELLO TOUR in JAKARTA DAY 2 AND HEAR THE SCREAAMMM', 'sentiment': 'Netral'}
# {'tweets_created': 'Sun Apr 16 17:48:27 +0000 2023', 'tweets_id': '1647658224462729217', 'tweets': '', 'sentiment': 'Netral'}
