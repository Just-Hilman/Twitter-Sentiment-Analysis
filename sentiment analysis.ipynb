# %%
import requests
import json
import pandas as pd

# %%
url = "https://twitter-data1.p.rapidapi.com/Search/"

querystring = {"q":"#TeddyOut","count":"20"}

headers = {
	"X-RapidAPI-Key": "a6129818camshba593fc1a0fb7dbp109dabjsn602bb7495377",
	"X-RapidAPI-Host": "twitter-data1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = json.loads(requests.get(url, headers=headers, params=querystring).text)

# %%
data

# %%
data_to_collect = data["globalObjects"]["tweets"]

# %%
data_to_collect.values()
# Out:
# dict_values([{'created_at': 'Sat Apr 15 17:16:55 +0000 2023', 'id': 1647287903267979265, 'id_str': '1647287903267979265', 'full_text': 'Well for this end match, see you next season #TeddyOut', 'truncated': False, 'display_text_range': [0, 54], 'entities': {'hashtags': [{'text': 'TeddyOut', 'indices': [45, 54]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 2318450815, 'user_id_str': '2318450815', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 93, 'favorite_count': 366, 'reply_count': 1, 'quote_count': 0, 'conversation_id': 1647287903267979265, 'conversation_id_str': '1647287903267979265', 'favorited': False, 'retweeted': False, 'lang': 'en', 'supplemental_language': None, 'ext_edit_control': {'initial': {'edit_tweet_ids': ['1647287903267979265'], 'editable_until_msecs': '1681580815000', 'edits_remaining': '5', 'is_edit_eligible': True}}, 'ext_views': {'state': 'EnabledWithCount', 'count': '32129'}, 'ext': {'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}, 'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1647287903267979265'], 'editableUntilMsecs': '1681580815000', 'editsRemaining': '5', 'isEditEligible': True}}}, 'ttl': -1}, 'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1}}}, {'created_at': 'Sun Apr 16 06:17:45 +0000 2023', 'id': 1647484403659198465, 'id_str': '1647484403659198465', 'full_text': 'Kalau masih ada @teddy_tjahjono persib gak akan pernah juara! \n#TeddyOut \n\n-abah gomez-', 'truncated': False, 'display_text_range': [0, 87], 'entities': {'hashtags': [{'text': 'TeddyOut', 'indices': [63, 72]}], 'symbols': [], 'user_mentions': [{'screen_name': 'teddy_tjahjono', 'name': 'Teddy Tjahjono', 'id': 4464729684, 'id_str': '4464729684', 'indices': [16, 31]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 3039961676, 'user_id_str': '3039961676', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 29, 'favorite_count': 161, 'reply_count': 11, 'quote_count': 2, 'conversation_id': 1647484403659198465, 'conversation_id_str': '1647484403659198465', 'favorited': False, 'retweeted': False, 'lang': 'in', 'supplemental_language': None, 'ext_edit_control': {'initial': {'edit_tweet_ids': ['1647484403659198465'], 'editable_until_msecs': '1681627665000', 'edits_remaining': '5', 'is_edit_eligible': True}}, 'ext_views': {'state': 'EnabledWithCount', 'count': '26856'}, 'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1}, 'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1647484403659198465'], 'editableUntilMsecs': '1681627665000', 'editsRemaining': '5', 'isEditEligible': True}}}, 'ttl': -1}, 'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}}, {'created_at': 'Wed Mar 01 14:32:44 +0000 2023', 'id': 1630939130182918145, 'id_str': '1630939130182918145', 'full_text': 'A take-anywhere door lock, silicone spikes that keep your shower clean, and a chunk of etched glass that smooths your feet.', 'truncated': False, 'display_text_range': [0, 123], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">advertiser-interface</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 18354034, 'user_id_str': '18354034', 'geo': None, 'coordinates': None, 'place': N ...

# %%
tweet_data = pd.DataFrame(columns=["tweet_created", "tweet_id", "tweet"])

for tweet in data_to_collect.values():
    tweet_created = tweet["created_at"]
    tweet_id = tweet["id_str"]
    tweet_value = tweet["full_text"]
    tweet_source = tweet["source"]
    tweet_data = tweet_data.append({"tweet_created": tweet_created, "tweet_id": tweet_id, "tweet": tweet_value, "tweet_source": tweet_source}, ignore_index=True)

# %%
my_new_string = tweet_data["tweet_source"].replace('<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', "Twitter for Android").replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', "Twitter for iPhone").replace('<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', "Twitter Web App").replace('<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">advertiser-interface</a>', "Other")

# %%
tweet_data["tweet_source"] = my_new_string
tweet_data
# Out:
#                      tweet_created             tweet_id  \
# 0   Sat Apr 15 17:16:55 +0000 2023  1647287903267979265
# 1   Sun Apr 16 06:17:45 +0000 2023  1647484403659198465
# 2   Wed Mar 01 14:32:44 +0000 2023  1630939130182918145
# 3   Sat Apr 15 17:24:27 +0000 2023  1647289797223018497
# 4   Sat Apr 15 06:30:03 +0000 2023  1647125114197270534
# 5   Sat Apr 15 17:57:14 +0000 2023  1647298045766426624
# 6   Sat Apr 15 17:14:33 +0000 2023  1647287304455847937
# 7   Sat Apr 15 16:18:45 +0000 2023  1647273263851270144
# 8   Sat Apr 15 04:49:44 +0000 2023  1647099867553210368
# 9   Sat Apr 15 17:23:00 +0000 2023  1647289432322760704
# 10  Sun Apr 16 06:13:46 +0000 2023  1647483400452988928
# 11  Sat Apr 15 09:27:24 +0000 2023  1647169744024535040
# 12  Sat Apr 15 16:58:46 +0000 2023  1647283333049749504
# 13  Sun Apr 16 04:43:22 +0000 2023  1647460650539704320
# 14  Sat Apr 15 06:45:49 +0000 2023  1647129078007488513
# 15  Sat Apr 15 18:28:46 +0000 2023  1647305983381884929
# 16  Sat Apr 15 17:18:04 +0000 2023  1647288189428850688
# 17  Sun Apr 16 01:25:28 +0000 2023  1647410847646638080
# 18  Sat Apr 15 17:54:34 +0000 2023  1647297375491493888
# 19  Sun Apr 16 14:16:37 +0000 2023  1647604915689381889
# 20  Sat Apr 15 17:22:53 +0000 2023  1647289405030420480
# 21  Sat Apr 15 18:54:12 +0000 2023  1647312385395531776
#
#                                                 tweet         tweet_source
# 0   Well for this end match, see you next season #...   Twitter for iPhone
# 1   Kalau masih ada @teddy_tjahjono persib gak aka...  Twitter for Android
# 2   A take-anywhere door lock, silicone spikes tha...                Other
# 3   My home is hell!!!!!!!! \n\n#TeddyOut https://...  Twitter for Android
# 4   once again, say it louder! #TeddyOut Fuck Mana...   Twitter for iPhone
# 5   I'M BOBOTOH NOT CUSTOMER\n#TeddyOut https://t....  Twitter for Android
# 6   I love Persib, and i want #TeddyOut https://t....   Twitter for iPhone
# 7   GELORA BANDUNG LAUTAN API\nBUKAN BUDAK TEDY\nT...  Twitter for Android
# 8   Dibanned akses untuk membeli tiket dikarenakan...  Twitter for Android
# 9   love persib hate management ⁦⁦@teddy_tjahjono⁩...   Twitter for iPhone
# 10  the #TeddyOut one!?%¥£%'*'&amp;*$ 😭😭😭 https://...  Twitter for Android
# 11  China Becky G The Script Lampung SOLD OUT #Ted...      Twitter Web App
# 12  Farewell, bli made🔥 \n\n#TeddyOut #TeddyOut #T...  Twitter for Android
# 13  Ughtea w*t mantap\n1. https://t.co/pKeB6Tfc5q\...  Twitter for Android
# 14                   PYRO IS NOT A CRIME\n\n#TEDDYOUT  Twitter for Android
# 15  see u next season !! 🙌#TeddyOut Manajemen gobl...   Twitter for iPhone
# 16  Last Match 🔥\n\n#TeddyOut https://t.co/3TzVdsPLxW   Twitter for iPhone
# 17  Bertindak seenak Baginda, maka kita juga bisa ...  Twitter for Android
# 18  2022.2023.Done ✅  #TeddyOut https://t.co/7VuM4...  Twitter for Android
# 19  You greedy bastard, get out of our club! #Tedd...  Twitter for Android
# 20  love tuhan persib dan mantan but i hate you te...  Twitter for Android
# 21  Bebasken lah goblog well \n#teddyout\n@teddy_t...  Twitter for Android

# %%
for tweets in data_to_collect.values():
    tweets_properties = {}
    tweets_properties["tweets_created"] = tweets["created_at"]
    tweets_properties["tweets_id"] = tweets["id_str"]
    tweets_properties["tweets"] = tweets["full_text"]
    tweets_properties["source"] = tweets["source"]
    print(tweets_properties)
