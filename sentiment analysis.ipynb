# %%
import requests
import json
import pandas as pd

# %%
url = "https://twitter-data1.p.rapidapi.com/Search/"

querystring = {"q":"Jakarta", "lang":"en", "count":"100"}

headers = {
	"X-RapidAPI-Key": "a6129818camshba593fc1a0fb7dbp109dabjsn602bb7495377",
	"X-RapidAPI-Host": "twitter-data1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = json.loads(requests.get(url, headers=headers, params=querystring).text)

# %%
data_to_collect = data["globalObjects"]["tweets"]

# %%
data_to_collect.values()
# Out:
# dict_values([{'created_at': 'Mon Apr 17 13:39:55 +0000 2023', 'id': 1647958065390526464, 'id_str': '1647958065390526464', 'full_text': 'EVENT: Cafe event in Indonesia - Vote for Jay Chang and get free drinks! 18-19th april all day\n\nOpen in Jakarta All branches:\n- SQP Gading Serpong (Main event with Jay banners)\n- Ciledug Tangerang\n- Perum Karawaci\n- Serang\n- Bintara Bekasi\n- Sunter Jakarta Utara\n- Margonda Depok https://t.co/ZOcoeoulMH', 'truncated': False, 'display_text_range': [0, 279], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1647958054023880705, 'id_str': '1647958054023880705', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/Ft65Hm7WYAEK4JQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ft65Hm7WYAEK4JQ.jpg', 'url': 'https://t.co/ZOcoeoulMH', 'display_url': 'pic.twitter.com/ZOcoeoulMH', 'expanded_url': 'https://twitter.com/jaycrewi/status/1647958065390526464/photo/1', 'type': 'photo', 'original_info': {'width': 1284, 'height': 1759, 'focus_rects': [{'x': 0, 'y': 1001, 'h': 719, 'w': 1284}, {'x': 0, 'y': 475, 'h': 1284, 'w': 1284}, {'x': 0, 'y': 295, 'h': 1464, 'w': 1284}, {'x': 404, 'y': 0, 'h': 1759, 'w': 880}, {'x': 0, 'y': 0, 'h': 1759, 'w': 1284}]}, 'sizes': {'large': {'w': 1284, 'h': 1759, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 876, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 496, 'h': 680, 'resize': 'fit'}}}, {'id': 1647958054019686403, 'id_str': '1647958054019686403', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/Ft65Hm6WYAM15gw.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ft65Hm6WYAM15gw.jpg', 'url': 'https://t.co/ZOcoeoulMH', 'display_url': 'pic.twitter.com/ZOcoeoulMH', 'expanded_url': 'https://twitter.com/jaycrewi/status/1647958065390526464/photo/1', 'type': 'photo', 'original_info': {'width': 1283, 'height': 1771, 'focus_rects': [{'x': 0, 'y': 1053, 'h': 718, 'w': 1283}, {'x': 0, 'y': 488, 'h': 1283, 'w': 1283}, {'x': 0, 'y': 308, 'h': 1463, 'w': 1283}, {'x': 0, 'y': 0, 'h': 1771, 'w': 886}, {'x': 0, 'y': 0, 'h': 1771, 'w': 1283}]}, 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1283, 'h': 1771, 'resize': 'fit'}, 'small': {'w': 493, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 869, 'h': 1200, 'resize': 'fit'}}}, {'id': 1647958054019760129, 'id_str': '1647958054019760129', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/Ft65Hm6XgAEZ7TU.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ft65Hm6XgAEZ7TU.jpg', 'url': 'https://t.co/ZOcoeoulMH', 'display_url': 'pic.twitter.com/ZOcoeoulMH', 'expanded_url': 'https://twitter.com/jaycrewi/status/1647958065390526464/photo/1', 'type': 'photo', 'original_info': {'width': 1283, 'height': 1744, 'focus_rects': [{'x': 0, 'y': 1026, 'h': 718, 'w': 1283}, {'x': 0, 'y': 461, 'h': 1283, 'w': 1283}, {'x': 0, 'y': 281, 'h': 1463, 'w': 1283}, {'x': 0, 'y': 0, 'h': 1744, 'w': 872}, {'x': 0, 'y': 0, 'h': 1744, 'w': 1283}]}, 'sizes': {'small': {'w': 500, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1283, 'h': 1744, 'resize': 'fit'}, 'medium': {'w': 883, 'h': 1200, 'resize': 'fit'}}}, {'id': 1647958054019780608, 'id_str': '1647958054019780608', 'indices': [280, 303], 'media_url': 'http://pbs.twimg.com/media/Ft65Hm6X0AAgpia.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ft65Hm6X0AAgpia.jpg', 'url': 'https://t.co/ZOcoeoulMH', 'display_url': 'pic.twitter.com/ZOcoeoulMH', 'expanded_url': 'https://twitter.com/jaycrewi/status/1647958065390526464/photo/1', 'type': 'photo', 'original_info': {'width': 1284, 'height': 1846, 'focus_rects': [{'x': 0, 'y': 0, 'h': 719, 'w': 1284}, {'x': 0, 'y': 0, 'h': 1284, 'w': 1284}, {'x': 0, 'y': 0, 'h': 1464, 'w': 1284}, {'x': 0, 'y': 0, 'h': 1846, 'w': 923}, {'x': 0, 'y': 0, 'h': 1846, 'w': 1284}]}, 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 835, 'h': 1200, 'resize': 'fit'}, 'small' ...

# %%
tweet_data = pd.DataFrame(columns=["tweet_created", "tweet_id", "tweet"])

for tweet in data_to_collect.values():
    tweet_created = tweet["created_at"]
    tweet_id = tweet["id_str"]
    tweet_value = tweet["full_text"]
    tweet_source = tweet["source"]
    tweet_data = tweet_data.append({"tweet_created": tweet_created, "tweet_id": tweet_id, "tweet": tweet_value, "tweet_source": tweet_source}, ignore_index=True)

# %%
my_new_string = tweet_data["tweet_source"].replace('<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', "Twitter for Android").replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', "Twitter for iPhone").replace('<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', "Twitter Web App").replace('<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">advertiser-interface</a>', "Other")

# %%
tweet_data["tweet_source"] = my_new_string
tweet_data
# Out:
#                      tweet_created             tweet_id  \
# 0   Mon Apr 17 13:39:55 +0000 2023  1647958065390526464
# 1   Mon Apr 17 14:12:22 +0000 2023  1647966234724675588
# 2   Mon Apr 17 07:13:04 +0000 2023  1647860711396352001
# 3   Mon Apr 17 05:31:27 +0000 2023  1647835139278528513
# 4   Mon Apr 17 02:38:45 +0000 2023  1647791680589033473
# 5   Mon Apr 17 09:59:20 +0000 2023  1647902556901736448
# 6   Mon Apr 17 14:14:01 +0000 2023  1647966649587228672
# 7   Sun Apr 16 14:40:23 +0000 2023  1647610897597358080
# 8   Sun Apr 16 07:34:21 +0000 2023  1647503683146633216
# 9   Mon Apr 17 07:35:33 +0000 2023  1647866373333454849
# 10  Mon Apr 17 06:18:25 +0000 2023  1647846960186146816
# 11  Mon Apr 17 13:54:56 +0000 2023  1647961848195473409
# 12  Fri Apr 14 09:02:31 +0000 2023  1646801095359098882
# 13  Mon Apr 17 10:07:42 +0000 2023  1647904661440184320
# 14  Mon Apr 17 02:49:37 +0000 2023  1647794415459770370
# 15  Mon Apr 17 14:21:11 +0000 2023  1647968451724734469
# 16  Mon Apr 17 10:33:04 +0000 2023  1647911044428476416
# 17  Mon Apr 17 12:33:56 +0000 2023  1647941464171892736
# 18  Mon Apr 17 09:37:43 +0000 2023  1647897115207823361
#
#                                                 tweet  \
# 0   EVENT: Cafe event in Indonesia - Vote for Jay ...
# 1   Freebies WayV Fanmeeting Tour [Phantom] in Jak...
# 2   [GIVEAWAY] WayV Fanmeet in Jakarta ᕕ( ᐛ )ᕗ\n\n...
# 3   A cool place in Jakarta is the basement of Blo...
# 4     siapa yg relate? wkwkwk https://t.co/wro9JhZaRP
# 5   CHARLES &amp; KEITH's global brand ambassadors...
# 6   The next president who is not Joko "Jokowi" Wi...
# 7   For Wayzennis who will attend Phantom in Jakar...
# 8   Giveaway 1 Tiket Fanmeet WayV atau Cash 1.785....
# 9   Trotoar &amp; jalur sepeda dibongkar katanya b...
# 10  Waduh Parah, Kini Jakarta kembali seperti dulu...
# 11  B.I 2023 Asia Tour [L.O.L THE HIDDEN STAGE] in...
# 12  Fujii Kaze and the piano Asia Tour\n\nJun 24th...
# 13  the jakarta woodz concert sold out in 5 minute...
# 14  i made this indomie inspired sign 🐑\n\n#YANGYA...
# 15  Happy tonight ayangg🥰🫶🏻\n\nJane Avail Vcs Now ...
# 16              He is here 🐊🔴 https://t.co/pUpiV6bG4r
# 17  Terjebak macet Jakarta, nyanyiin aja deh lagu ...
# 18     kegundahan kita semua: https://t.co/3oguqMfMK0
#
#                                          tweet_source
# 0                                  Twitter for iPhone
# 1                                  Twitter for iPhone
# 2                                 Twitter for Android
# 3                                  Twitter for iPhone
# 4                                  Twitter for iPhone
# 5   <a href="https://sproutsocial.com" rel="nofoll...
# 6   <a href="https://www.thejakartapost.com/" rel=...
# 7                                  Twitter for iPhone
# 8                                 Twitter for Android
# 9                                 Twitter for Android
# 10                                Twitter for Android
# 11                                Twitter for Android
# 12                                    Twitter Web App
# 13                                 Twitter for iPhone
# 14                                 Twitter for iPhone
# 15                                 Twitter for iPhone
# 16                                 Twitter for iPhone
# 17                                 Twitter for iPhone
# 18                                 Twitter for iPhone

# %%
import re
from textblob import TextBlob

# %%
for tweets in data_to_collect.values():
    tweets_properties = {}
    tweets_properties["tweets_created"] = tweets["created_at"]
    tweets_properties["tweets_id"] = tweets["id_str"]
    tweets_properties["tweets"] = tweets["full_text"]
    tweets_properties["source"] = tweets["source"].replace('<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', "Twitter for Android").replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', "Twitter for iPhone").replace('<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', "Twitter Web App").replace('<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">advertiser-interface</a>', "Other")
    cleaned_tweets = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweets["full_text"]).split())

    analysis = TextBlob(cleaned_tweets)
    print(analysis.sentiment.polarity)
# Out:
# 0.18888888888888888
# 0.0
# 0.0
# 0.25
# 0.0
# 0.38666666666666666
# 0.14444444444444446
# 0.3
# 0.0
# 0.0
# 0.0
# -0.16666666666666666
# 0.0
# -1.0
# 0.0
# 0.8
# 0.0
# 0.35
# 0.0
